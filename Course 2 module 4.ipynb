# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# **LAMIU** <br>Business Analtsis

# %% [markdown]
# *I am interested in data science because I like help people to do data-driven decision.*

# %% [markdown]
# <h3>I want to know 1+1=?<h3>

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# ***

# %% [markdown]
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |

# %% [markdown]
#  - one
#  - two
